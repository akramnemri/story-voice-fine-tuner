# %% [markdown]
# # Story-Voice Fine-Tuner – Step 1: Setup
# **Gradio UI version** (professor-approved)
#
# This notebook sets up everything we need:
# - GPU runtime
# - All free libraries (Transformers, Datasets, Gradio, etc.)
# - Folder structure ready for VS Code later

# %%
# Check GPU is active
import torch
print("✅ GPU is ready!" if torch.cuda.is_available() else "❌ No GPU – go to Runtime → Change runtime type")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# ✅ GPU is ready!
# GPU: Tesla T4

# %%
# Install everything we need (100% free)
# !pip install -q transformers datasets accelerate evaluate gradio huggingface_hub

print("✅ All libraries installed successfully!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.6 MB/s eta 0:00:00
# ✅ All libraries installed successfully!

# %%
# Import everything we'll use in the whole project
import torch
from transformers import (
    GPT2LMHeadModel,
    GPT2Tokenizer,
    Trainer,
    TrainingArguments,
    DataCollatorForLanguageModeling
)
from datasets import load_dataset, Dataset
import gradio as gr
import evaluate
import os
from datetime import datetime

print("✅ All imports ready!")
print(f"PyTorch version: {torch.__version__}")
print(f"Transformers version: {__import__('transformers').__version__}")
print(f"Gradio version: {gr.__version__}")
# Out:
# ✅ All imports ready!
# PyTorch version: 2.10.0+cu128
# Transformers version: 5.0.0
# Gradio version: 5.50.0
